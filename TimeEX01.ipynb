# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Time_Series/nasa_exoplanet_intelligence.csv')
df.head(10)
# Out:
#      planet_name    host_star  n_stars  n_planets discovery_method  disc_year  \
# 0  Kepler-1167 b  Kepler-1167        1          1          Transit     2016.0
# 1  Kepler-1740 b  Kepler-1740        1          1          Transit     2021.0
# 2  Kepler-1581 b  Kepler-1581        1          1          Transit     2016.0
# 3   Kepler-644 b   Kepler-644        1          1          Transit     2016.0
# 4  Kepler-1752 b  Kepler-1752        1          1          Transit     2021.0
# 5   Kepler-280 c   Kepler-280        1          2          Transit     2014.0
# 6  Kepler-1208 b  Kepler-1208        1          1          Transit     2016.0
# 7   Kepler-263 c   Kepler-263        1          2          Transit     2014.0
# 8  Kepler-1101 b  Kepler-1101        1          1          Transit     2016.0
# 9    HD 168746 b    HD 168746        1          1  Radial Velocity     2002.0
#
#           disc_facility  orbital_period_days  planet_radius_earth  \
# 0                Kepler             1.003934             1.710000
# 1                Kepler             8.172400             3.323214
# 2                Kepler             6.283855             0.800000
# 3                Kepler             3.173917             3.150000
# 4                Kepler            56.358501             4.540605
# 5                Kepler             4.807091             2.010000
# 6                Kepler            11.085076             2.320000
# 7                Kepler            47.332773             2.470000
# 8                Kepler            81.315106             2.470000
# 9  La Silla Observatory             6.404000            11.100000
#
#    planet_mass_earth  ...          ra        dec  controversial_flag  \
# 0             3.5700  ...  298.302660  47.693965                   0
# 1            11.0000  ...  293.873663  38.922455                   0
# 2             0.4370  ...  287.371320  39.603623                   0
# 3            10.1000  ...  295.475702  43.493112                   0
# 4            18.7000  ...  290.854140  51.222743                   0
# 5             4.7000  ...  291.390533  42.180473                   0
# 6             5.9900  ...  291.881244  44.555759                   0
# 7             6.6600  ...  292.469802  37.567794                   0
# 8             6.6600  ...  294.569354  45.671162                   0
# 9            85.8141  ...  275.457327 -11.922976                   0
#
#     planet_type  habitable_zone_flag  multi_planet_system  \
# 0   Super-Earth                False                False
# 1  Mini-Neptune                False                False
# 2     Sub-Earth                False                False
# 3  Mini-Neptune                False                False
# 4  Neptune-like                False                False
# 5  Mini-Neptune                False                 True
# 6  Mini-Neptune                False                False
# 7  Mini-Neptune                 True                 True
# 8  Mini-Neptune                 True                False
# 9     Gas Giant                False                False
#
#    is_recent_discovery   dist_category         star_type  orbital_period_cat
# 0                False   Far(500-2kpc)            K-type        Short(1-10d)
# 1                 True   Far(500-2kpc)  G-type(Sun-like)        Short(1-10d)
# 2                False  Mid(100-500pc)            F-type        Short(1-10d)
# 3                False   Far(500-2kpc)            F-type        Short(1-10d)
# 4                 True   Far(500-2kpc)  G-type(Sun-like)     Medium(10-100d)
# 5                False   Far(500-2kpc)  G-type(Sun-like)        Short(1-10d)
# 6                False   Far(500-2kpc)            K-type     Medium(10-100d)
# 7                False   Far(500-2kpc)  G-type(Sun-like)     Medium(10-100d)
# 8                False   Far(500-2kpc)  G-type(Sun-like)     Medium(10-100d)
# 9                False  Nearby(<100pc)  G-type(Sun-like)        Short(1-10d)
#
# [10 rows x 31 columns]

# %%
df['disc_year'] = pd.to_datetime(df['disc_year'], format='%Y')

# %%
df.dtypes
# Out:
# planet_name                     object
# host_star                       object
# n_stars                          int64
# n_planets                        int64
# discovery_method                object
# disc_year               datetime64[ns]
# disc_facility                   object
# orbital_period_days            float64
# planet_radius_earth            float64
# planet_mass_earth              float64
# equilibrium_temp_k             float64
# orbital_eccentricity           float64
# semi_major_axis_au             float64
# star_temp_k                    float64
# star_radius_sun                float64
# star_mass_sun                  float64
# star_age_gyr                   float64
# star_surface_gravity           float64
# star_metallicity               float64
# dist_from_earth_pc             float64
# star_vmag                      float64
# ra                             float64
# dec                            float64
# controversial_flag               int64
# planet_type                     object
# habitable_zone_flag               bool
# multi_planet_system               bool
# is_recent_discovery               bool
# dist_category                   object
# star_type                       object
# orbital_period_cat              object
# dtype: object

# %%
yearly_data = df.groupby('disc_year')['star_temp_k'].mean()

yearly_data.plot(kind='line', marker='o')
plt.title('Average Temperature of Stars')
plt.xlabel('Year')
plt.ylabel('Average Temperature in Kelvin')
plt.grid(True)
plt.show()
